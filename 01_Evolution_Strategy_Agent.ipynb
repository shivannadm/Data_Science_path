# %% [markdown]
# <a href="https://colab.research.google.com/github/shivannadm/Data_Science_path/blob/main/01_Evolution_Strategy_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Reference:** https://github.com/huseinzol05/Stock-Prediction-Models

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# <ipython-input-2-b20a6bd7f956>:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
# matplotlib==3.8.0
# numpy==1.26.4
# pandas==2.2.2
# seaborn==0.13.2

# %%
def get_state(data, t, n):
    d = t - n + 1
    block = data[d : t + 1] if d >= 0 else -d * [data[0]] + data[0 : t + 1]
    res = []
    for i in range(n - 1):
        res.append(block[i + 1] - block[i])
    return np.array([res])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/TSLA.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-03-23  311.250000  311.250000  300.450012  301.540009  301.540009
# 1  2018-03-26  307.339996  307.589996  291.359985  304.179993  304.179993
# 2  2018-03-27  304.000000  304.269989  277.179993  279.179993  279.179993
# 3  2018-03-28  264.579987  268.679993  252.100006  257.779999  257.779999
# 4  2018-03-29  256.489990  270.959991  248.210007  266.130005  266.130005
#
#      Volume
# 0   6654900
# 1   8375200
# 2  13872000
# 3  21001400
# 4  15170700

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
l = len(close) - 1

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / np.std(rewards)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(layer_size, 1),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        buy = np.dot(feed, self.weights[2])
        return decision, buy

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, money, max_buy, max_sell):
        self.model = model
        self.initial_money = money
        self.max_buy = max_buy
        self.max_sell = max_sell
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision, buy = self.model.predict(np.array(sequence))
        return np.argmax(decision[0]), int(buy[0])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = get_state(close, 0, window_size + 1)
        inventory = []
        quantity = 0
        for t in range(0, l, skip):
            action, buy = self.act(state)
            next_state = get_state(close, t + 1, window_size + 1)
            if action == 1 and initial_money >= close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
            elif action == 2 and len(inventory) > 0:
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                quantity -= sell_units
                total_sell = sell_units * close[t]
                initial_money += total_sell

            state = next_state
        return ((initial_money - starting_money) / starting_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = get_state(close, 0, window_size + 1)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        quantity = 0
        for t in range(0, l, skip):
            action, buy = self.act(state)
            next_state = get_state(close, t + 1, window_size + 1)
            if action == 1 and initial_money >= close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
                states_buy.append(t)
                print(
                    'day %d: buy %d units at price %f, total balance %f'
                    % (t, buy_units, total_buy, initial_money)
                )
            elif action == 2 and len(inventory) > 0:
                bought_price = inventory.pop(0)
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                if sell_units < 1:
                    continue
                quantity -= sell_units
                total_sell = sell_units * close[t]
                initial_money += total_sell
                states_sell.append(t)
                try:
                    invest = ((total_sell - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (t, sell_units, total_sell, invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        print(
            '\ntotal gained %f, total investment %f %%'
            % (initial_money - starting_money, invest)
        )
        plt.figure(figsize = (20, 10))
        plt.plot(close, label = 'true close', c = 'g')
        plt.plot(
            close, 'X', label = 'predict buy', markevery = states_buy, c = 'b'
        )
        plt.plot(
            close, 'o', label = 'predict sell', markevery = states_sell, c = 'r'
        )
        plt.legend()
        plt.show()

# %%
model = Model(window_size, 500, 3)
agent = Agent(model, 10000, 5, 5)
agent.fit(500, 10)
# Out:
# <ipython-input-9-c0336f8adf32>:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return np.argmax(decision[0]), int(buy[0])
# iter 10. reward: 36.288900
# iter 20. reward: 43.598099
# iter 30. reward: 55.814102
# iter 40. reward: 61.252001
# iter 50. reward: 70.101297
# iter 60. reward: 73.744300
# iter 70. reward: 69.841102
# iter 80. reward: 72.245301
# iter 90. reward: 79.666400
# iter 100. reward: 82.985702
# iter 110. reward: 79.738698
# iter 120. reward: 79.032996
# iter 130. reward: 79.160398
# iter 140. reward: 80.133100
# iter 150. reward: 85.411897
# iter 160. reward: 83.395801
# iter 170. reward: 88.956000
# iter 180. reward: 93.599901
# iter 190. reward: 97.053301
# iter 200. reward: 96.408699
# iter 210. reward: 92.941202
# iter 220. reward: 98.868600
# iter 230. reward: 93.713700
# iter 240. reward: 93.705802
# iter 250. reward: 105.288703
# iter 260. reward: 92.224400
# iter 270. reward: 103.698900
# iter 280. reward: 102.083595
# iter 290. reward: 107.328000
# iter 300. reward: 108.165602
# iter 310. reward: 108.272702
# iter 320. reward: 105.644504
# iter 330. reward: 110.435002
# iter 340. reward: 107.419502
# iter 350. reward: 110.245301
# iter 360. reward: 106.853900
# iter 370. reward: 105.857300
# iter 380. reward: 109.152997
# iter 390. reward: 107.326899
# iter 400. reward: 104.793702
# iter 410. reward: 100.965701
# iter 420. reward: 105.627700
# iter 430. reward: 106.946399
# iter 440. reward: 107.316799
# iter 450. reward: 113.211702
# iter 460. reward: 113.913101
# iter 470. reward: 114.627102
# iter 480. reward: 113.336602
# iter 490. reward: 113.415303
# iter 500. reward: 117.093601
# time taken to train: 105.52700090408325 seconds

# %%
agent.buy()
# Out:
# day 0: buy 5 units at price 1507.700045, total balance 8492.299955
# day 1, sell 5 units at price 1520.899965, investment 0.875500 %, total balance 10013.199920,
# day 3: buy 5 units at price 1288.899995, total balance 8724.299925
# day 4: buy 5 units at price 1330.650025, total balance 7393.649900
# day 5: buy 5 units at price 1262.399980, total balance 6131.249920
# day 6: buy 5 units at price 1337.649995, total balance 4793.599925
# day 7, sell 5 units at price 1434.700010, investment 11.311973 %, total balance 6228.299935,
# day 8, sell 5 units at price 1528.600005, investment 14.876187 %, total balance 7756.899940,
# day 10: buy 1 units at price 289.660004, total balance 7467.239936
# day 11, sell 5 units at price 1523.500060, investment 20.682833 %, total balance 8990.739996,
# day 12, sell 5 units at price 1504.649965, investment 12.484579 %, total balance 10495.389961,
# day 13: buy 5 units at price 1470.399935, total balance 9024.990026
# day 14, sell 5 units at price 1501.699980, investment 418.435393 %, total balance 10526.690006,
# day 15, sell 1 units at price 291.209991, investment -80.195185 %, total balance 10817.899997,
# day 16: buy 5 units at price 1438.450010, total balance 9379.449987
# day 17: buy 1 units at price 293.350006, total balance 9086.099981
# day 18, sell 5 units at price 1500.399935, investment 4.306714 %, total balance 10586.499916,
# day 19, sell 1 units at price 290.239990, investment -1.060172 %, total balance 10876.739906,
# day 20: buy 1 units at price 283.369995, total balance 10593.369911
# day 21, sell 1 units at price 283.459991, investment 0.031759 %, total balance 10876.829902,
# day 23: buy 5 units at price 1427.400055, total balance 9449.429847
# day 24: buy 5 units at price 1470.399935, total balance 7979.029912
# day 26: buy 1 units at price 299.920013, total balance 7679.109899
# day 27: buy 1 units at price 301.149994, total balance 7377.959905
# day 28: buy 5 units at price 1422.250060, total balance 5955.709845
# day 29, sell 5 units at price 1470.449980, investment 3.015968 %, total balance 7426.159825,
# day 30, sell 5 units at price 1513.849945, investment 2.954979 %, total balance 8940.009770,
# day 32, sell 5 units at price 1534.250030, investment 411.553069 %, total balance 10474.259800,
# day 33, sell 2 units at price 610.039978, investment 102.570144 %, total balance 11084.299778,
# day 34: buy 5 units at price 1505.299990, total balance 9578.999788
# day 36: buy 5 units at price 1420.899965, total balance 8158.099823
# day 37: buy 5 units at price 1432.400055, total balance 6725.699768
# day 39: buy 5 units at price 1384.100035, total balance 5341.599733
# day 40: buy 5 units at price 1422.449950, total balance 3919.149783
# day 42: buy 1 units at price 279.070007, total balance 3640.079776
# day 43: buy 1 units at price 277.850006, total balance 3362.229770
# day 44: buy 5 units at price 1394.250030, total balance 1967.979740
# day 45: buy 5 units at price 1418.800050, total balance 549.179690
# day 46: buy 5 units at price 1458.600005, total balance -909.420315
# day 49, sell 5 units at price 1483.699950, investment 4.320611 %, total balance 574.279635,
# day 50: buy 5 units at price 1455.650025, total balance -881.370390
# day 51, sell 5 units at price 1597.500000, investment 6.125026 %, total balance 716.129610,
# day 52, sell 5 units at price 1580.449980, investment 11.228800 %, total balance 2296.579590,
# day 53: buy 5 units at price 1588.300020, total balance 708.279570
# day 55, sell 5 units at price 1713.849945, investment 19.648833 %, total balance 2422.129515,
# day 56, sell 5 units at price 1723.899995, investment 24.550246 %, total balance 4146.029510,
# day 57, sell 5 units at price 1788.600005, investment 25.740804 %, total balance 5934.629515,
# day 58, sell 5 units at price 1790.850065, investment 541.720722 %, total balance 7725.479580,
# day 59, sell 5 units at price 1854.149935, investment 567.320459 %, total balance 9579.629515,
# day 60, sell 5 units at price 1762.749940, investment 26.429973 %, total balance 11342.379455,
# day 61, sell 5 units at price 1811.100005, investment 27.650123 %, total balance 13153.479460,
# day 62, sell 2 units at price 695.020020, investment -52.350198 %, total balance 13848.499480,
# day 63: buy 5 units at price 1668.150025, total balance 12180.349455
# day 64: buy 1 units at price 333.010010, total balance 11847.339445
# day 65, sell 5 units at price 1710.000000, investment 17.473292 %, total balance 13557.339445,
# day 67: buy 1 units at price 349.929993, total balance 13207.409452
# day 70: buy 1 units at price 310.859985, total balance 12896.549467
# day 71: buy 5 units at price 1545.800020, total balance 11350.749447
# day 73: buy 5 units at price 1592.550050, total balance 9758.199397
# day 77: buy 5 units at price 1594.349975, total balance 8163.849422
# day 78: buy 5 units at price 1550.500030, total balance 6613.349392
# day 79, sell 5 units at price 1613.450010, investment 1.583453 %, total balance 8226.799402,
# day 80, sell 5 units at price 1619.250030, investment -2.931391 %, total balance 9846.049432,
# day 81: buy 5 units at price 1601.150055, total balance 8244.899377
# day 83: buy 5 units at price 1516.000060, total balance 6728.899317
# day 84: buy 5 units at price 1487.149965, total balance 5241.749352
# day 85: buy 1 units at price 308.739990, total balance 4933.009362
# day 86: buy 5 units at price 1533.249970, total balance 3399.759392
# day 87: buy 5 units at price 1485.899965, total balance 1913.859427
# day 89: buy 5 units at price 1490.700075, total balance 423.159352
# day 91, sell 5 units at price 1747.700045, investment 424.819072 %, total balance 2170.859397,
# day 92, sell 5 units at price 1740.850065, investment 397.485240 %, total balance 3911.709462,
# day 93: buy 1 units at price 341.989990, total balance 3569.719472
# day 94, sell 5 units at price 1897.850035, investment 510.516029 %, total balance 5467.569507,
# day 95, sell 5 units at price 1851.699980, investment 19.789103 %, total balance 7319.269487,
# day 97, sell 5 units at price 1777.449950, investment 11.610304 %, total balance 9096.719437,
# day 98, sell 5 units at price 1782.050020, investment 11.772826 %, total balance 10878.769457,
# day 99, sell 5 units at price 1738.200075, investment 12.105775 %, total balance 12616.969532,
# day 100, sell 5 units at price 1693.450010, investment 5.764604 %, total balance 14310.419542,
# day 101, sell 5 units at price 1677.250060, investment 10.636543 %, total balance 15987.669602,
# day 103: buy 1 units at price 308.440002, total balance 15679.229600
# day 104, sell 1 units at price 321.899994, investment -78.354571 %, total balance 16001.129594,
# day 113: buy 5 units at price 1444.750060, total balance 14556.379534
# day 114: buy 5 units at price 1403.699950, total balance 13152.679584
# day 116: buy 5 units at price 1316.199950, total balance 11836.479634
# day 117: buy 5 units at price 1427.500000, total balance 10408.979634
# day 119: buy 5 units at price 1452.700045, total balance 8956.279589
# day 120: buy 5 units at price 1447.299955, total balance 7508.979634
# day 121: buy 5 units at price 1476.000060, total balance 6032.979574
# day 123: buy 5 units at price 1424.799955, total balance 4608.179619
# day 124: buy 1 units at price 299.019989, total balance 4309.159630
# day 125, sell 5 units at price 1491.649935, investment 3.246228 %, total balance 5800.809565,
# day 126: buy 1 units at price 299.100006, total balance 5501.709559
# day 127, sell 5 units at price 1498.399965, investment 6.746457 %, total balance 7000.109524,
# day 129, sell 5 units at price 1547.899935, investment 17.603707 %, total balance 8548.009459,
# day 130, sell 5 units at price 1537.599945, investment 7.712781 %, total balance 10085.609404,
# day 131: buy 1 units at price 264.769989, total balance 9820.839415
# day 132, sell 5 units at price 1553.500060, investment 6.938804 %, total balance 11374.339475,
# day 133, sell 5 units at price 1505.099945, investment 3.993643 %, total balance 12879.439420,
# day 134: buy 5 units at price 1473.999940, total balance 11405.439480
# day 136: buy 5 units at price 1309.750060, total balance 10095.689420
# day 137: buy 5 units at price 1252.799990, total balance 8842.889430
# day 138: buy 1 units at price 262.799988, total balance 8580.089442
# day 139: buy 5 units at price 1284.400025, total balance 7295.689417
# day 140: buy 5 units at price 1261.149980, total balance 6034.539437
# day 142: buy 5 units at price 1297.949980, total balance 4736.589457
# day 145: buy 5 units at price 1319.550020, total balance 3417.039437
# day 146: buy 5 units at price 1300.000000, total balance 2117.039437
# day 148: buy 5 units at price 1470.700075, total balance 646.339362
# day 150, sell 5 units at price 1574.299925, investment 6.659882 %, total balance 2220.639287,
# day 151, sell 5 units at price 1654.499970, investment 16.121562 %, total balance 3875.139257,
# day 152, sell 5 units at price 1674.250030, investment 459.912411 %, total balance 5549.389287,
# day 154, sell 5 units at price 1686.600035, investment 463.891675 %, total balance 7235.989322,
# day 155, sell 5 units at price 1721.399995, investment 550.149211 %, total balance 8957.389317,
# day 157, sell 5 units at price 1706.999970, investment 15.807330 %, total balance 10664.389287,
# day 158, sell 5 units at price 1705.299990, investment 30.200413 %, total balance 12369.689277,
# day 159, sell 5 units at price 1740.800020, investment 38.952749 %, total balance 14110.489297,
# day 160: buy 1 units at price 351.399994, total balance 13759.089303
# day 161, sell 5 units at price 1752.550050, investment 566.876001 %, total balance 15511.639353,
# day 163, sell 5 units at price 1693.650055, investment 31.863128 %, total balance 17205.289408,
# day 164, sell 5 units at price 1720.000000, investment 36.383462 %, total balance 18925.289408,
# day 167: buy 1 units at price 353.470001, total balance 18571.819407
# day 168: buy 1 units at price 347.489990, total balance 18224.329417
# day 170: buy 5 units at price 1629.149935, total balance 16595.179482
# day 171: buy 5 units at price 1730.000000, total balance 14865.179482
# day 172, sell 5 units at price 1719.600065, investment 32.485850 %, total balance 16584.779547,
# day 173, sell 5 units at price 1739.349975, investment 31.813872 %, total balance 18324.129522,
# day 174, sell 5 units at price 1705.850065, investment 31.219236 %, total balance 20029.979587,
# day 176: buy 5 units at price 1792.449950, total balance 18237.529637
# day 177: buy 5 units at price 1798.500060, total balance 16439.029577
# day 179, sell 5 units at price 1789.850005, investment 21.700545 %, total balance 18228.879582,
# day 180: buy 1 units at price 365.149994, total balance 17863.729588
# day 181, sell 5 units at price 1833.800050, investment 421.855459 %, total balance 19697.529638,
# day 184, sell 3 units at price 1097.129973, investment 210.388426 %, total balance 20794.659611,
# day 185: buy 1 units at price 348.420013, total balance 20446.239598
# day 186, sell 1 units at price 337.029999, investment -3.010156 %, total balance 20783.269597,
# day 187: buy 5 units at price 1664.850005, total balance 19118.419592
# day 188: buy 5 units at price 1576.900025, total balance 17541.519567
# day 189: buy 1 units at price 319.769989, total balance 17221.749578
# day 191: buy 1 units at price 326.089996, total balance 16895.659582
# day 193: buy 5 units at price 1669.349975, total balance 15226.309607
# day 195: buy 5 units at price 1550.599975, total balance 13675.709632
# day 196: buy 5 units at price 1501.799925, total balance 12173.909707
# day 197, sell 5 units at price 1588.450010, investment -2.498231 %, total balance 13762.359717,
# day 201, sell 5 units at price 1724.850005, investment -0.297688 %, total balance 15487.209722,
# day 202, sell 5 units at price 1736.300050, investment -3.132578 %, total balance 17223.509772,
# day 203: buy 5 units at price 1671.999970, total balance 15551.509802
# day 204, sell 5 units at price 1722.149965, investment -4.245209 %, total balance 17273.659767,
# day 205, sell 5 units at price 1730.249940, investment 373.846356 %, total balance 19003.909707,
# day 206, sell 5 units at price 1736.549990, investment 398.407073 %, total balance 20740.459697,
# day 207, sell 2 units at price 604.520020, investment -63.689220 %, total balance 21344.979717,
# day 208: buy 1 units at price 298.920013, total balance 21046.059704
# day 209: buy 5 units at price 1437.949980, total balance 19608.109724
# day 210: buy 5 units at price 1457.550050, total balance 18150.559674
# day 211: buy 1 units at price 297.040009, total balance 17853.519665
# day 212, sell 5 units at price 1481.900025, investment -6.024478 %, total balance 19335.419690,
# day 213: buy 1 units at price 297.459991, total balance 19037.959699
# day 214: buy 5 units at price 1543.849945, total balance 17494.109754
# day 217, sell 5 units at price 1564.450075, investment 389.242308 %, total balance 19058.559829,
# day 218: buy 5 units at price 1606.750030, total balance 17451.809799
# day 219, sell 5 units at price 1586.100005, investment 386.399468 %, total balance 19037.909804,
# day 220: buy 5 units at price 1537.550050, total balance 17500.359754
# day 222, sell 5 units at price 1564.199980, investment -6.298859 %, total balance 19064.559734,
# day 223, sell 5 units at price 1559.049990, investment 0.544951 %, total balance 20623.609724,
# day 224, sell 3 units at price 924.510039, investment -38.439866 %, total balance 21548.119763,
# day 238: buy 5 units at price 1381.199950, total balance 20166.919813
# day 240, sell 5 units at price 1420.700075, investment 2.859841 %, total balance 21587.619888,
# day 243: buy 5 units at price 1444.799955, total balance 20142.819933
# day 244, sell 5 units at price 1449.799955, investment 0.346069 %, total balance 21592.619888,
# day 246: buy 5 units at price 1347.449950, total balance 20245.169938
# day 247, sell 5 units at price 1337.350005, investment -0.749560 %, total balance 21582.519943,
#
# total gained 11582.519943, total investment 115.825199 %
# <ipython-input-9-c0336f8adf32>:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return np.argmax(decision[0]), int(buy[0])
