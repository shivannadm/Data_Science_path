# %% [markdown]
# <a href="https://colab.research.google.com/github/shivannadm/Data_Science_path/blob/main/Lab_Exercise_06_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NASSCOM Internship 2024-2025
# # Lab Exercise **06** Data Science.
# Unsupervised Machine learning Algorithms

# %% [markdown]
# # Lab 01 & 02: INTRODUCTION

# %% [markdown]
# Unsupervised learning is a machine learning approach where the model is trained on data without labeled outputs. Instead of predicting an output, it finds patterns, relationships, or structures in the data. The most common tasks in unsupervised learning are clustering, dimensionality reduction, and anomaly detection.
#
# **Key Concepts of Unsupervised Learning**
#
# *Unsupervised Learning vs. Supervised Learning*
#
# * **Supervised Learning:** Works with labeled data to predict outcomes (e.g., predicting house prices).
# * **Unsupervised Learning:** Works with unlabeled data to uncover hidden patterns (e.g., grouping customers by purchasing behavior).
#
# *Common Tasks in Unsupervised Learning*:
#
# * **Clustering:** Grouping data points based on similarity.
# Example: Customer segmentation for targeted marketing.
# * **Dimensionality Reduction:** Reducing the number of features while retaining important information.
# Example: Visualizing high-dimensional data in 2D or 3D.
# * **Anomaly Detection:** Identifying rare items, events, or observations that deviate from the norm.
# Example: Detecting fraudulent transactions.

# %%
# 1. Import Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Example dataset: Customer income and spending
data = pd.DataFrame({
    'Income': [15, 16, 16, 17, 18, 30, 32, 34, 35, 40, 41, 42],
    'Spending': [39, 40, 42, 44, 45, 20, 22, 24, 25, 11, 10, 9]
})

# Visualize the data
plt.scatter(data['Income'], data['Spending'], color='blue')
plt.xlabel('Income')
plt.ylabel('Spending')
plt.title('Income vs Spending')
plt.show()

# %%
# 3. Apply K-Means Clustering
# Initialize K-Means with 2 clusters
kmeans = KMeans(n_clusters=2, random_state=42)

# Fit the model to the data
kmeans.fit(data)

# Get the cluster assignments
data['Cluster'] = kmeans.labels_

# Visualize the clusters
colors = ['red', 'green']
for cluster in range(2):
    cluster_data = data[data['Cluster'] == cluster]
    plt.scatter(cluster_data['Income'], cluster_data['Spending'], color=colors[cluster], label=f'Cluster {cluster}')

# Mark centroids
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], color='black', marker='X', s=100, label='Centroids')

plt.xlabel('Income')
plt.ylabel('Spending')
plt.title('K-Means Clustering')
plt.legend()
plt.show()

# %% [markdown]
# **Interpret Results**
#
# * Each cluster represents a group of data points with similar spending habits and income levels.
# * Centroids are the central points of each cluster and can be used as reference points for new data.
#
# **Outcomes of the Lab**
#
# 1. Understand the Idea:
#   * Unsupervised learning doesn't rely on labels but instead detects inherent patterns or groups in the data.
# 2. Explore K-Means:
#   * Learn how clustering works and its practical use cases.
# 3. Visualize:
#    * Use data visualization to interpret the results of unsupervised learning.

# %% [markdown]
# # Lab 03: K-Means Clustering
# Objective: Implement K-Means Clustering

# %% [markdown]
# K-Means Clustering is a popular unsupervised learning algorithm that divides data into
# <code>k</code> clusters. It minimizes the variance within each cluster while maximizing the variance between clusters.

# %% [markdown]
# **1. Import Necessary Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# **2. Create or Load a Dataset**

# %%
# Example dataset: Customer income and spending habits
data = pd.DataFrame({
    'Income': [15, 16, 16, 17, 18, 30, 32, 34, 35, 40, 41, 42],
    'Spending': [39, 40, 42, 44, 45, 20, 22, 24, 25, 11, 10, 9]
})

# Visualize the raw data
plt.scatter(data['Income'], data['Spending'], color='blue')
plt.xlabel('Income')
plt.ylabel('Spending')
plt.title('Income vs Spending')
plt.show()

# %% [markdown]
# **3. Apply K-Means Clustering**

# %%
# Define the number of clusters
k = 3

# Initialize the K-Means algorithm
kmeans = KMeans(n_clusters=k, random_state=42)

# Fit the model to the data
kmeans.fit(data)

# Add cluster labels to the dataset
data['Cluster'] = kmeans.labels_

# %% [markdown]
# **4. Visualize the Clusters**

# %%
# Assign colors to clusters
colors = ['red', 'green', 'blue']

# Plot each cluster
for cluster in range(k):
    cluster_data = data[data['Cluster'] == cluster]
    plt.scatter(cluster_data['Income'], cluster_data['Spending'], color=colors[cluster], label=f'Cluster {cluster}')

# Plot centroids
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1], color='black', marker='X', s=100, label='Centroids')

plt.xlabel('Income')
plt.ylabel('Spending')
plt.title('K-Means Clustering Results')
plt.legend()
plt.show()

# %% [markdown]
# **5. Evaluate the Clustering**
#
# Evaluate how well the data fits into clusters using the Inertia value (sum of squared distances to the nearest centroid):

# %%
print("Inertia (Sum of Squared Distances):", kmeans.inertia_)
# Out:
# Inertia (Sum of Squared Distances): 64.69999999999999

# %% [markdown]
# **6.Determine Optimal k Using the Elbow Method**
#
# The Elbow Method helps choose the optimal number of clusters (k) by plotting inertia for different k values and finding the "elbow" point.

# %%
# Calculate inertia for different values of k
inertia = []
k_values = range(1, 10)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data[['Income', 'Spending']])
    inertia.append(kmeans.inertia_)

# Plot the Elbow Curve
plt.plot(k_values, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()

# %% [markdown]
# **Expected Results**
# 1. Cluster Visualization:
# A scatter plot showing clusters with distinct colors and centroids.
#
# 2. Optimal 𝑘 (Elbow Method):
# The elbow point on the curve suggests the best number of clusters.
#
# 3. Cluster Labels:
# Each data point in the dataset is assigned to a cluster, available in the Cluster column.
#
# **Outcomes of the Lab**
#
# 1. Understand how K-Means Clustering works and its parameters like 𝑘.
# 2. Learn to assign clusters to data points and interpret the results.
# 3. Use the Elbow Method to determine the optimal number of clusters.
# 4. Visualize clustering results for better insights.
